# %% [markdown]
# ISCX Neural Network
# =================

# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten
from keras.layers.normalization import BatchNormalization

from livelossplot import PlotLossesKeras

from ann_visualizer.visualize import ann_viz

# %%
from keras.utils import to_categorical


def load_data(csv_path, x_features):
    
    # read CSV
    data = pd.read_csv(csv_path, header='infer')

    # shuffle data
    data.reindex(np.random.permutation(data.index))

    # separate X and Y
    X_all = data[x_features]
    y_all = data["label"]

    # Reformat y (labels) to one-hot encoding
    y_all_cat = to_categorical(y_all)

    # get number of rows in X
    m = X_all.shape[0]

    # split dataset for train and test 2 to 1
    X_train = X_all.iloc[0:2*m//3].values
    X_test = X_all.iloc[2*m//3:m].values

    y_train = y_all_cat[0:2*m//3]
    y_test = y_all_cat[2*m//3:m]
    
    return (X_train, y_train), (X_test, y_test)

# %% [markdown]
# Load data
# -------------

# %%
(X_train, y_train), (X_test, y_test) = load_data(
    "csv/iscx_processed_005b.csv",
    ("%s_%03d" % (p, i) for p in ("p", "d", "t") for i in range(1, 31))
)

print("Data is loaded (%d entries)" % X_train.shape[0])
# Out:
# Data is loaded (6398 entries)

# %% [markdown]
# Test 1
# -------
#
# Packet size, direction, inter-arrival times per flows

# %%
(X_train, y_train), (X_test, y_test) = load_data(
    "csv/iscx_processed_005b.csv",
    ("%s_%03d" % (p, i) for p in ("p", "d", "t") for i in range(1, 31))
)

print("Data is loaded (%d entries)" % X_train.shape[0])
# Out:
# Data is loaded (6398 entries)

# %%
n, f = X_train.shape
_, c = y_train.shape

#reshape
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#create model
model = Sequential()

#add model layers
model.add(BatchNormalization())
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(f, 1)))
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(c, activation='softmax'))

# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from livelossplot import PlotLossesKeras

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    0.945, max:    3.183, cur:    0.954)
# validation (min:    2.261, max:    3.061, cur:    2.548)
#
# Accuracy:
# training   (min:    0.161, max:    0.690, cur:    0.689)
# validation (min:    0.159, max:    0.493, cur:    0.491)

# %% [markdown]
# Dense FFN
# ----------------------

# %%
N, f = X_train.shape
_, c = y_train.shape

#create model
model = Sequential()

#add model layers
model.add(BatchNormalization(input_shape=(f,)))
model.add(Dense(c, activation='softmax'))

# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_13 (Batc (None, 90)                360
# _________________________________________________________________
# dense_23 (Dense)             (None, 58)                5278
# =================================================================
# Total params: 5,638
# Trainable params: 5,458
# Non-trainable params: 180
# _________________________________________________________________
# None

# %%
from livelossplot import PlotLossesKeras

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    2.091, max:    3.701, cur:    2.111)
# validation (min:    2.635, max:    3.304, cur:    2.760)
#
# Accuracy:
# training   (min:    0.117, max:    0.396, cur:    0.390)
# validation (min:    0.177, max:    0.353, cur:    0.339)

# %% [markdown]
# Dense FFN (2 layers)
# -----------------------

# %%
N, f = X_train.shape
_, c = y_train.shape

#create model
model = Sequential()

#add model layers
model.add(BatchNormalization(input_shape=(f,)))
model.add(Dense(40, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(c, activation='softmax'))

# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_16 (Batc (None, 90)                360
# _________________________________________________________________
# dense_30 (Dense)             (None, 40)                3640
# _________________________________________________________________
# dense_31 (Dense)             (None, 20)                820
# _________________________________________________________________
# dense_32 (Dense)             (None, 58)                1218
# =================================================================
# Total params: 6,038
# Trainable params: 5,858
# Non-trainable params: 180
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    1.712, max:    3.291, cur:    1.719)
# validation (min:    2.352, max:    3.030, cur:    2.397)
#
# Accuracy:
# training   (min:    0.151, max:    0.482, cur:    0.475)
# validation (min:    0.185, max:    0.385, cur:    0.383)
